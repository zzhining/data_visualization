# %% [markdown]
# <a href="https://colab.research.google.com/github/zzhining/data_visualization/blob/main/exercise/cancer_skeleton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 데이터 셋 로드- cancer_b.csv(양성데이터), cancer_m.csv(악성데이터)
cancer_b_data = pd.read_csv("https://raw.githubusercontent.com/zzhining/data_visualization/main/dataset/cancer_b.csv?token=GHSAT0AAAAAAB4ACKNOBJ5MCFOFJG2HLKS6Y4N2AKA", index_col="Id")
cancer_m_data = pd.read_csv("https://raw.githubusercontent.com/zzhining/data_visualization/main/dataset/cancer_m.csv?token=GHSAT0AAAAAAB4ACKNOGZ4ZJYBRMSNPMBX6Y4N2AVQ", index_col="Id")
cancer = pd.concat([cancer_b_data, cancer_m_data])

# %% [markdown]
# # Q1.
# 데이터 프레임 `cancer`는 총 몇 개의 인스턴스와 컬럼으로 구성되어있는지 확인하시오.

# %%
# 코드를 작성하세요.

# %% [markdown]
# #Q2.
# `Diagnosis` 컬럼은 환자가 악성 종양(M)인지, 양성 종양(B)인지를 표시할 때, 악성, 양성 환자의 수를 구하시오

# %%
# 코드를 작성하세요.

# %% [markdown]
# # Q3.
# `Area (mean)`에 따라 `Diagnosis` 진단 여부가 달라지는지 확인하려고 한다. `Area (mean)`의 분포를 `Diagnosis`의 유형에 대해 나누어 시각화하시오.

# %%
# 코드를 작성하세요.

# %% [markdown]
#  # Q4.
#  최근 한 병원에서 종양을 정확하게 진단 할 수 있는 알고리즘을 사용하기 시작했다.
#
#  'Radius (worst)'값이 25인 종양이 주어질 경우,
#  * 종양을 Benign(양성)으로 분류할 가능성이 더 높은지,
#  * 아니면 Malignant(악성)으로 분류 할 가능성이 더 높은지
#  데이터 시각화를 통해 확인하시오.

# %%
# 코드를 작성하세요.

# %% [markdown]
# # Q5.
# 각 컬럼의 속성별 분포가 양성/악성 종양 판단에 영향을 주는지 확인하기 위해 히스토그램을 그리려고 한다. 모든 컬럼에 대해 아래와 같이 히스토그램을 한 눈에 확인할 수 있도록 코드를 작성하시오.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 코드를 작성하세요.
