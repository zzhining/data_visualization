# %% [markdown]
# <a href="https://colab.research.google.com/github/zzhining/data_visualization/blob/main/exercise/seaborn_stock_dashboard_skeleton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 대시 보드 예시

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 데이터 불러오기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_datareader import data
import yfinance as yfin
sns.set_palette('Set2')

yfin.pdr_override()

# 엔비디아, 2023년 1월1일~현재
df = data.get_data_yahoo('NVDA', start = '2023-01-01')
df.tail()

# %% [markdown]
# # 차트1) 종가 기준 선 그래프

# %% [markdown]
# # 차트2) 월별 종가 평균

# %% [markdown]
# # 차트3) 상승/하락 비교 파이차트

# %% [markdown]
# # 차트4) 요일별 상승/하락 비교

# %% [markdown]
# # 차트 5) 전체
